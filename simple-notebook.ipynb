# %%
import pandas as pd

data = {
    "name": ["Alice", "Bob", "Charlie"],
    "score": [85, 92, 78]
}

df = pd.DataFrame(data)

print(df)
print(df.describe())
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     92
# 2  Charlie     78
#        score
# count    3.0
# mean    85.0
# std      7.0
# min     78.0
# 25%     81.5
# 50%     85.0
# 75%     88.5
# max     92.0
